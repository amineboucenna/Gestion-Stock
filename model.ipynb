# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import squarify
import seaborn as sns

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

from wordcloud import WordCloud

# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

    ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

    ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

    ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

   ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
df = pd.DataFrame(data=dataset)

# %%
plt.rcParams['figure.figsize'] = (15, 15)

wordcloud = WordCloud(background_color = 'white', width = 1200,  height = 1200, max_words = 121).generate(str(y[0])
plt.axis('off')
plt.title('Most Popular Items',fontsize = 20)
plt.show()
                                                                                                          plt.imshow(wordcloud)
plt.imshow(wordcloud)
# Out:
#   File "C:\Users\HP\AppData\Local\Temp/ipykernel_508/4274300305.py", line 4
#     plt.axis('off')
#     ^
# SyntaxError: invalid syntax

# %%
plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 40))
pd.DataFrame(df[0]).value_counts().plot.bar(color = color)
plt.title('frequency of most popular items', fontsize = 20)
plt.xticks(rotation = 90 )
plt.grid()
plt.show()

# %%
y = (df[0]).value_counts().to_frame()

# %%
y = (df[0]).value_counts().to_frame()
y.index
# Out:
# Index(['Dress', 'Skirt', 'Sunglasses', 'Earrings'], dtype='object')

# %%
y1.index
# Out:
# Index(['Skirt', 'Sneakers', 'Sandals', 'Necklace'], dtype='object')

# %%
plt.rcParams['figure.figsize'] = (20, 20)
color = plt.cm.cool(np.linspace(0, 15, 50))
squarify.plot(sizes = y.values, label = y.index, alpha=.8, color = color)
plt.title('Tree Map for Popular Items')
plt.axis('off')
plt.show()

# %%
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)    #Apply one-hot-encoding on our dataset
datasetaset=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
dataset=pd.DataFrame(te_ary, columns=te.columns_) 

from mlxtend.frequent_patterns import apriori
frequent_itemsets=apriori(dataset, min_support=0.6, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Pants, Scarf)
# 5      0.6  (Pants, Skirt)

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.3)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 1     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 2     (Pants)     (Skirt)                 0.8                 0.6      0.6
# 3     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence    lift  leverage  conviction
# 0        0.75  0.9375     -0.04         0.8
# 1        0.75  0.9375     -0.04         0.8
# 2        0.75  1.2500      0.12         1.6
# 3        1.00  1.2500      0.12         inf

# %%
data=pd.read_csv('C:\\Users\\HP\\Documents\\dataset\\Market_Basket_Optimisation.csv', header=None)

# %%
data.shape
# Out:
# (7501, 20)

# %%
data.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
data.describe()
# Out:
#                    0              1              2              3          4   \
# count            7501           5747           4389           3345       2529
# unique            115            117            115            114        110
# top     mineral water  mineral water  mineral water  mineral water  green tea
# freq              577            484            375            201        153
#
#                   5          6          7          8          9   \
# count           1864       1369        981        654        395
# unique           106        102         98         88         80
# top     french fries  green tea  green tea  green tea  green tea
# freq             107         96         67         57         31
#
#                     10         11         12         13         14      15  \
# count              256        154         87         47         25       8
# unique              66         50         43         28         19       8
# ...

# %%
plt.rcParams['figure.figsize'] = (15, 15)

wordcloud = WordCloud(background_color = 'white', width = 1200,  height = 1200, max_words = 121).generate(str(data[0]))
plt.imshow(wordcloud)
plt.axis('off')
plt.title('Most Popular Items',fontsize = 20)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 40))
data[0].value_counts().head(40).plot.bar(color = color)
plt.title('frequency of most popular items', fontsize = 20)
plt.xticks(rotation = 90 )
plt.grid()
plt.show()

# %%
y = data[0].value_counts().head(50).to_frame()
y.index
# Out:
# Index(['mineral water', 'burgers', 'turkey', 'chocolate', 'frozen vegetables',
#        'spaghetti', 'shrimp', 'grated cheese', 'eggs', 'cookies',
#        'french fries', 'herb & pepper', 'ground beef', 'tomatoes', 'milk',
#        'escalope', 'fresh tuna', 'red wine', 'ham', 'cake', 'green tea',
#        'whole wheat pasta', 'pancakes', 'soup', 'muffins', 'energy bar',
#        'olive oil', 'champagne', 'pepper', 'avocado', 'butter',
#        'parmesan cheese', 'whole wheat rice', 'low fat yogurt', 'chicken',
#        'vegetables mix', 'pickles', 'meatballs', 'frozen smoothie',
#        'yogurt cake', 'salmon', 'dessert wine', 'hot dogs', 'honey',
#        'candy bars', 'cereals', 'strawberries', 'yams', 'oil', 'tomato sauce'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize'] = (20, 20)
color = plt.cm.cool(np.linspace(0, 5, 50))
squarify.plot(sizes = y.values, label = y.index, alpha=.8, color = color)
plt.title('Tree Map for Popular Items')
plt.axis('off')
plt.show()

# %%
trans = []
for i in range(0, 7501):
    trans.append([str(data.values[i,j]) for j in range(0, 20)])

# conveting it into an numpy array
trans = np.array(trans)

# checking the shape of the array
print(trans.shape)
# Out:
# (7501, 20)

# %%
te = TransactionEncoder()
data = te.fit_transform(trans)
data = pd.DataFrame(data, columns = te.columns_)

# getting the shape of the data
data.shape
# Out:
# (7501, 121)

# %%
data=data.drop('nan',axis=1)

# %%
data
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
# Support
frequent_itemsets = apriori(data, min_support = 0.05, use_colnames = True) # Select itemsets with a minimum of 5% support
frequent_itemsets.sort_values(by = "support", ascending = False)
# Out:
#      support                    itemsets
# 16  0.238368             (mineral water)
# 6   0.179709                      (eggs)
# 21  0.174110                 (spaghetti)
# 8   0.170911              (french fries)
# 3   0.163845                 (chocolate)
# 12  0.132116                 (green tea)
# 15  0.129583                      (milk)
# 13  0.098254               (ground beef)
# 10  0.095321         (frozen vegetables)
# 18  0.095054                  (pancakes)
# 0   0.087188                   (burgers)
# 1   0.081056                      (cake)
# 4   0.080389                   (cookies)
# 7   0.079323                  (escalope)
# 14  0.076523            (low fat yogurt)
# 19  0.071457                    (shrimp)
# 22  0.068391                  (tomatoes)
# 17  0.065858                 (olive oil)
# 9   0.063325           (frozen smoothie)
# 23  0.062525                    (turkey)
# 2   0.059992                   (chicken)
# 27  0.059725  (mineral water, spaghetti)
# ...

# %% [markdown]
# (mineral water), (eggs), (spaghetti), (french fries) and (chocolate) are the most frequent itemsets in the dataset.

# %%
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.2).sort_values(by = "confidence", ascending = False)
# Out:
#                     antecedents          consequents  antecedent support  \
# 133         (eggs, ground beef)      (mineral water)            0.019997
# 150         (milk, ground beef)      (mineral water)            0.021997
# 122    (chocolate, ground beef)      (mineral water)            0.023064
# 144   (milk, frozen vegetables)      (mineral water)            0.023597
# 100                      (soup)      (mineral water)            0.050527
# ..                          ...                  ...                 ...
# 21               (french fries)          (chocolate)            0.170911
# 147  (mineral water, spaghetti)  (frozen vegetables)            0.059725
# 74                  (green tea)          (spaghetti)            0.132116
# 34                       (soup)          (chocolate)            0.050527
# 3                     (burgers)          (green tea)            0.087188
#
#      consequent support   support  confidence      lift  leverage  conviction
# ...

# %% [markdown]
# <ul>
#
#   <li>We have a 51% chance to buy <strong>mineral water  </strong> with  <strong>eggs and ground beef.</strong>.</li>
#     <br>
#   <li>We have a 50% chance to buy <strong>mineral water</strong> with <strong>milk and ground beef.</strong>.</li>
#         <br>
#    <li>We have a 47% chance to buy <strong>mineral water a </strong> with <strong>ground beef and chocolate. </strong>.</li>
# </ul>

# %%
association_rules(frequent_itemsets, metric = "lift", min_threshold = 1).sort_values(by = "lift", ascending = False)
# Out:
#                     antecedents                 consequents  \
# 214             (herb & pepper)               (ground beef)
# 215               (ground beef)             (herb & pepper)
# 387               (ground beef)  (mineral water, spaghetti)
# 382  (mineral water, spaghetti)               (ground beef)
# 396  (mineral water, spaghetti)                 (olive oil)
# ..                          ...                         ...
# 155              (french fries)            (low fat yogurt)
# 131                      (eggs)                 (olive oil)
# 130                 (olive oil)                      (eggs)
# 144                  (escalope)                 (spaghetti)
# 145                 (spaghetti)                  (escalope)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 214            0.049460            0.098254  0.015998    0.323450  3.291994
# 215            0.098254            0.049460  0.015998    0.162822  3.291994
# ...

# %% [markdown]
# <ul>
#
#   <li>It s more likely to buy <strong>herb, pepper and ground beef </strong> rather than <strong>ground beef or herf and pepper alone </strong>.</li>
#     <br>
#   <li>It s more likely to buy <strong>spaghetti, mineral water and ground beef </strong> rather than <strong>ground beef alone </strong>.</li>
#         <br>
#
#    <li>It s more likely to buy <strong>spaghetti, mineral water and olive oil </strong> rather than <strong>ground beef alone </strong>.</li>
# </ul>
